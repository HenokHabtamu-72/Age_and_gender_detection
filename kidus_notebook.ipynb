# %%
# import pandas as pd
# import numpy as np



# data = pd.read_csv(r"C:\Users\henok\data\outputs\results\utkface_metadata.csv")
# data.drop(["age_bucket_excel"],axis = "columns", inplace = True)


# def match_age_with_range(age: int):
#     if age in range(0, 3): return "0-2"
#     elif age in range(3, 8): return "4-9"
#     elif age in range(8,14): return "8-12"
#     elif age in range(14, 24): return "15-20"
#     elif age in range(24,35): return "25-32" 
#     elif age in range(35,46): return "38-43" 
#     elif age in range(46, 65): return "48-53" 
#     elif age in range(65, 111): return "60-100"

# age = np.array(data.age)
# age_bucket_fixed = np.array(map(match_age_with_range, age))
# data["age_bucket"] = age_bucket_fixed
# data.age_bucket.astype("str")
# data.loc[data["age"] == 14]

# data.to_csv(r"C:\Users\henok\Data\outputs\results\utkface_metadata_1.csv")

# %%
import pandas as pd

grades = pd.read_excel(
    r"C:\Users\henok\OneDrive - Higher Colleges of Technology\Desktop\!Sixth Semester\ICT 2013-Computational Thinking and Coding\LAB\Marks.xlsx",
    sheet_name="Grades",
    skiprows=3
)

# c. Remove rows where all values are null (permanently)
grades.dropna(how='all', inplace=True)

# d. Replace all null values with 0 (permanently)
grades.fillna(0, inplace=True)

# e. Rename columns (permanently)
grades.rename(columns={"ID ": "ID", "Final": "FWA"}, inplace=True)

# (optional) check result
print(grades.head())
# Out:
#        ID Division  Quiz  Practical  Project   FWA
# 0  H00247      EDU  84.0       67.0     69.6  67.0
# 1  H00258      HLT  74.0       68.0     67.0  73.0
# 2  H00269      ENG  88.0       86.0     75.6  74.0
# 3  H00224      EDU   0.0       71.0     65.8  71.0
# 4  H00269      EDU  22.0       65.0     66.8  78.0
# c:\Users\henok\data\.venv\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
